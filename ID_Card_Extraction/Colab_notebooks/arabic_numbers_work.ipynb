# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pytesseract

# %%
# !unzip /content/drive/MyDrive/ID_Card_Extraction/Colab/Egyptian_National_ID_Number_OCR-main.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/ID_Card_Extraction/Colab/Egyptian_National_ID_Number_OCR-main.zip, /content/drive/MyDrive/ID_Card_Extraction/Colab/Egyptian_National_ID_Number_OCR-main.zip.zip or /content/drive/MyDrive/ID_Card_Extraction/Colab/Egyptian_National_ID_Number_OCR-main.zip.ZIP.

# %%
# !sudo apt-get install tesseract-ocr

# %%
# !mv /content/Egyptian_National_ID_Number_OCR-main/arabic_numbers.traineddata /usr/share/tesseract-ocr/4.00/tessdata/
# Out:
# mv: cannot stat '/content/Egyptian_National_ID_Number_OCR-main/arabic_numbers.traineddata': No such file or directory

# %%
# !python egypt_id_ocr.py --input /content/Egyptian_National_ID_Number_OCR-main/photo_5899756851371818771_y.jpg
# Out:
# python3: can't open file 'egypt_id_ocr.py': [Errno 2] No such file or directory
